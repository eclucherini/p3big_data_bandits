# %%
# Dependencies
from pathlib import Path
from sqlalchemy import create_engine, text

import pandas as pd

# %%
# NOTE: that due to the size of the data, these SQLite tables have been significantly reduced only to show the SQLite pathway and SQLAlchemy pull.
# We host our cleaned CSV files on our local drives in order to use and continue our analysis.

# Create a reference to the database 
database_path = Path("sample_airbnb.db")

# Create Engine
engine = create_engine(f"sqlite:///{database_path}")

# %%
# Select all data from the three New York AirBnb tables 
query_ny_reviews = text("SELECT * FROM sample_ny_reviews;")
sample_ny_review_data = engine.execute(query_ny_reviews)

sample_ny_review_df = pd.DataFrame(sample_ny_review_data)
sample_ny_review_df.head()
# Out:
#    listing_id     id        date  reviewer_id reviewer_name  \
# 0        2595  17857  11/21/2009        50679          Jean
# 1        2595  19176   12/5/2009        53267          Cate
# 2        2595  19760  12/10/2009        38960         Anita
# 3        2595  34320    4/9/2010        71130       Kai-Uwe
# 4        2595  46312   5/25/2010       117113        Alicia
#
#                                             comments
# 0  Notre séjour de trois nuits.\r<br/>Nous avons ...
# 1                                  Great experience.
# 2  I've stayed with my friend at the Midtown Cast...
# 3  We've been staying here for about 9 nights, en...
# 4  We had a wonderful stay at Jennifer's charming...

# %%
# sample_ny_review_df.columns
sample_ny_reviews_cleaned = sample_ny_review_df[['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name']]

sample_ny_reviews_cleaned.head()
# Out:
#    listing_id     id        date  reviewer_id reviewer_name
# 0        2595  17857  11/21/2009        50679          Jean
# 1        2595  19176   12/5/2009        53267          Cate
# 2        2595  19760  12/10/2009        38960         Anita
# 3        2595  34320    4/9/2010        71130       Kai-Uwe
# 4        2595  46312   5/25/2010       117113        Alicia

# %%
query_ny_listings = text("SELECT * FROM sample_ny_listings;")
sample_ny_listings_data = engine.execute(query_ny_listings)

sample_ny_listings_df = pd.DataFrame(sample_ny_listings_data)
sample_ny_listings_df.head()
# Out:
#       id                         listing_url     scrape_id last_scraped  \
# 0   2595   https://www.airbnb.com/rooms/2595  2.023060e+13     6/5/2023
# 1   5121   https://www.airbnb.com/rooms/5121  2.023060e+13     6/5/2023
# 2  14991  https://www.airbnb.com/rooms/14991  2.023060e+13     6/5/2023
# 3   5136   https://www.airbnb.com/rooms/5136  2.023060e+13     6/5/2023
# 4  15341  https://www.airbnb.com/rooms/15341  2.023060e+13     6/5/2023
#
#             source                                               name  \
# 0      city scrape  Rental unit in New York · ★4.68 · Studio · 1 b...
# 1  previous scrape  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...
# 2      city scrape  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 3      city scrape  Rental unit in Brooklyn · ★5.0 · 2 bedrooms · ...
# 4      city scrape  Condo in New York · ★4.56 · 1 bedroom · 2 beds...
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  One room available for rent in a 2 bedroom apt...
# 2  Room for rent in my Manhattan apartment. The a...
# 3  We welcome you to stay in our lovely 2 br dupl...
# 4  Greetings! <br /><br />Come relax here after y...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  This 1-bedroom apartment is conveniently locat...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...     2845  ...
# 1  https://a0.muscache.com/pictures/2090980c-b68e...     7356  ...
# 2  https://a0.muscache.com/pictures/56919050/b99e...    59023  ...
# 3  https://a0.muscache.com/pictures/miso/Hosting-...     7378  ...
# 4  https://a0.muscache.com/pictures/16faf1ad-cb1f...    60049  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.80                   4.81                4.40
# 1                        4.91                   4.47                4.52
# 2                        4.92                   4.92                4.85
# 3                        5.00                   4.67                5.00
# 4                        4.80                   4.71                4.34
#
#   license instant_bookable calculated_host_listings_count  \
# 0    None                f                              3
# 1    None                f                              2
# 2    None                f                              1
# 3    None                f                              1
# 4    None                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.30
# 1                                           0              0.29
# 2                                           0              0.14
# 3                                           0              0.03
# 4                                           0              0.30
#
# [5 rows x 75 columns]

# %%
sample_ny_listing_cleaned = sample_ny_listings_df[['id', 'listing_url', 'name', 'host_id', 'host_url', 'host_name', 'host_since', 'host_is_superhost', 'host_listings_count', 'host_total_listings_count', 'latitude', 'longitude', 
'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights', 'has_availability', 'number_of_reviews', 
'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'last_review', 'review_scores_rating', 'calculated_host_listings_count', 'reviews_per_month']]

sample_ny_listing_cleaned.head()
# Out:
#       id                         listing_url  \
# 0   2595   https://www.airbnb.com/rooms/2595
# 1   5121   https://www.airbnb.com/rooms/5121
# 2  14991  https://www.airbnb.com/rooms/14991
# 3   5136   https://www.airbnb.com/rooms/5136
# 4  15341  https://www.airbnb.com/rooms/15341
#
#                                                 name  host_id  \
# 0  Rental unit in New York · ★4.68 · Studio · 1 b...     2845
# 1  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...     7356
# 2  Rental unit in New York · ★4.93 · 1 bedroom · ...    59023
# 3  Rental unit in Brooklyn · ★5.0 · 2 bedrooms · ...     7378
# 4  Condo in New York · ★4.56 · 1 bedroom · 2 beds...    60049
#
#                                   host_url host_name host_since  \
# 0   https://www.airbnb.com/users/show/2845  Jennifer   9/9/2008
# 1   https://www.airbnb.com/users/show/7356     Garon   2/3/2009
# 2  https://www.airbnb.com/users/show/59023    Bianca  12/1/2009
# 3   https://www.airbnb.com/users/show/7378   Rebecca   2/3/2009
# 4  https://www.airbnb.com/users/show/60049       Ted  12/4/2009
#
#   host_is_superhost  host_listings_count  host_total_listings_count  ...  \
# 0                 f                    7                          9  ...
# 1              None                    2                          2  ...
# 2              None                    1                          3  ...
# 3                 f                    1                          5  ...
# 4                 f                    1                          3  ...
#
#    maximum_nights  has_availability number_of_reviews number_of_reviews_ltm  \
# 0            1125                 t                49                     1
# 1             730                 t                50                     0
# 2              15                 t                22                     3
# 3            1125                 t                 3                     1
# 4            1125                 t                35                     4
#
#    number_of_reviews_l30d first_review last_review  review_scores_rating  \
# 0                       0   11/21/2009   6/21/2022                  4.68
# 1                       0    5/28/2009   12/2/2019                  4.52
# 2                       1    3/21/2010   5/14/2023                  4.93
# 3                       0     1/2/2014   8/10/2022                  5.00
# 4                       1    10/1/2013   5/23/2023                  4.56
#
#   calculated_host_listings_count  reviews_per_month
# 0                              3               0.30
# 1                              2               0.29
# 2                              1               0.14
# 3                              1               0.03
# 4                              1               0.30
#
# [5 rows x 30 columns]

# %%
query_ny_calendar = text("SELECT * FROM sample_ny_calendar;")
sample_ny_calendar_data = engine.execute(query_ny_calendar)

sample_ny_calendar_df = pd.DataFrame(sample_ny_calendar_data)
sample_ny_calendar_df.head()
# Out:
#    listing_id       date available    price adjusted_price  minimum_nights  \
# 0        2539   9/7/2022         f  $299.00        $299.00              30
# 1        2539   9/8/2022         f  $299.00        $299.00              30
# 2        2539   9/9/2022         f  $299.00        $299.00              30
# 3        2539  9/10/2022         f  $299.00        $299.00              30
# 4        2539  9/11/2022         f  $299.00        $299.00              30
#
#    maximum_nights
# 0             730
# 1             730
# 2             730
# 3             730
# 4             730

# %%
# sample_ny_calendar_df.columns

sample_ny_calendar_cleaned = sample_ny_calendar_df[['listing_id', 'date', 'available', 'price', 'adjusted_price']]

sample_ny_calendar_cleaned.head()
# Out:
#    listing_id       date available    price adjusted_price
# 0        2539   9/7/2022         f  $299.00        $299.00
# 1        2539   9/8/2022         f  $299.00        $299.00
# 2        2539   9/9/2022         f  $299.00        $299.00
# 3        2539  9/10/2022         f  $299.00        $299.00
# 4        2539  9/11/2022         f  $299.00        $299.00
